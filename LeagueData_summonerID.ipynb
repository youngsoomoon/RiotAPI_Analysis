# %%
import requests
import json
import pandas as pd
import numpy as np
import pymongo

# %%
from pymongo import MongoClient
client = MongoClient()
db = client.RiotAPI
iron2_user_collection = db.league_iron2_user
bronze2_user_collection = db.league_bronze2_user
silver2_user_collection = db.league_silver2_user
gold2_user_collection = db.league_gold2_user
platinum2_user_collection = db.league_platinum2_user
diamond2_user_collection = db.league_diamond2_user

# %%
api_key = 'RGAPI-00c762c6-d921-45fe-82cb-885cf056c10c'


Tier_Iron = "https://kr.api.riotgames.com/lol/league/v4/entries/RANKED_SOLO_5x5/IRON/II?page=1&api_key="+api_key
Tier_Bronze = "https://kr.api.riotgames.com/lol/league/v4/entries/RANKED_SOLO_5x5/BRONZE/II?page=1&api_key="+api_key
Tier_Silver = "https://kr.api.riotgames.com/lol/league/v4/entries/RANKED_SOLO_5x5/SILVER/II?page=1&api_key="+api_key
Tier_Gold = "https://kr.api.riotgames.com/lol/league/v4/entries/RANKED_SOLO_5x5/GOLD/II?page=1&api_key="+api_key
Tier_Platinum = "https://kr.api.riotgames.com/lol/league/v4/entries/RANKED_SOLO_5x5/PLATINUM/II?page=1&api_key="+api_key
Tier_Diamond = "https://kr.api.riotgames.com/lol/league/v4/entries/RANKED_SOLO_5x5/DIAMOND/II?page=1&api_key="+api_key

r_Iron = requests.get(Tier_Iron)
r_Bronze = requests.get(Tier_Bronze)
r_Silver = requests.get(Tier_Silver)
r_Gold = requests.get(Tier_Gold)
r_Platinum = requests.get(Tier_Platinum)
r_Diamond = requests.get(Tier_Diamond)

r_Iron.json()
r_Bronze.json()
r_Silver.json()
r_Gold.json()
r_Platinum.json()
r_Diamond.json()
# Out:
# [{'leagueId': 'a2622f31-b789-4c8c-898f-273fe2154b38',
#   'queueType': 'RANKED_SOLO_5x5',
#   'tier': 'DIAMOND',
#   'rank': 'II',
#   'summonerId': 'iQnZcatXMPZ-VzscK2vvpEWRN5gluq5wIIg8xuXzl8e40vl_',
#   'summonerName': '99 JGL',
#   'leaguePoints': 38,
#   'wins': 40,
#   'losses': 40,
#   'veteran': False,
#   'inactive': False,
#   'freshBlood': False,
#   'hotStreak': False},
#  {'leagueId': '8609519e-e883-43ad-9d03-1b59339f368d',
#   'queueType': 'RANKED_SOLO_5x5',
#   'tier': 'DIAMOND',
#   'rank': 'II',
#   'summonerId': 'cNJSrfCOs4Y8Oal-s0Gdrr0od-Je83BjfW_k-4DqLxMdWdJE',
#   'summonerName': 'FriendIy',
#   'leaguePoints': 75,
#   'wins': 31,
#   'losses': 25,
#   'veteran': False,
#   'inactive': False,
#   'freshBlood': False,
#   'hotStreak': False},
#  {'leagueId': '0dbc305d-2d2f-4ca5-8825-928aa01adf6a',
#   'queueType': 'RANKED_SOLO_5x5',
#   'tier': 'DIAMOND',
#   'rank': 'II',
#   'summonerId': 'XQPWr-b5WRpOV75Mmnum853pWiu7v3thTJbk2Qxz7qYKIbbx',
# ...

# %%
iron2_user_collection.insert_many(r_Iron.json())
bronze2_user_collection.insert_many(r_Bronze.json())
silver2_user_collection.insert_many(r_Silver.json())
gold2_user_collection.insert_many(r_Gold.json())
platinum2_user_collection.insert_many(r_Platinum.json())
diamond2_user_collection.insert_many(r_Diamond.json())

# %%
for i in silver2_user_collection.find():
    print(i)
# Out:
# {'_id': ObjectId('606ec2048ffd9b98a8de3407'), 'leagueId': 'e7ea0eb9-afea-4784-8ab0-f651c01ec3c9', 'queueType': 'RANKED_SOLO_5x5', 'tier': 'SILVER', 'rank': 'II', 'summonerId': 'pB5_6VnZ-JAYoOowH6CEj8I26fZVVuQFzJ_QSf8Of8Iqs54L', 'summonerName': '신동아학원', 'leaguePoints': 33, 'wins': 36, 'losses': 30, 'veteran': False, 'inactive': False, 'freshBlood': False, 'hotStreak': False}
# {'_id': ObjectId('606ec2048ffd9b98a8de3408'), 'leagueId': '474dcc25-bd48-48f0-8c31-6f3cb211947f', 'queueType': 'RANKED_SOLO_5x5', 'tier': 'SILVER', 'rank': 'II', 'summonerId': 'KmP_miGUpX2MZt04VCoK4anorZFDweJvBPNCj_FrnA520HFH', 'summonerName': '나는미래의대머리', 'leaguePoints': 17, 'wins': 18, 'losses': 14, 'veteran': False, 'inactive': False, 'freshBlood': True, 'hotStreak': True}
# ...

# %%
# Out:
# [{'leagueId': 'a2622f31-b789-4c8c-898f-273fe2154b38',
#   'queueType': 'RANKED_SOLO_5x5',
#   'tier': 'DIAMOND',
#   'rank': 'II',
#   'summonerId': 'iQnZcatXMPZ-VzscK2vvpEWRN5gluq5wIIg8xuXzl8e40vl_',
#   'summonerName': '99 JGL',
#   'leaguePoints': 38,
#   'wins': 40,
#   'losses': 40,
#   'veteran': False,
#   'inactive': False,
#   'freshBlood': False,
#   'hotStreak': False},
#  {'leagueId': '8609519e-e883-43ad-9d03-1b59339f368d',
#   'queueType': 'RANKED_SOLO_5x5',
#   'tier': 'DIAMOND',
#   'rank': 'II',
#   'summonerId': 'cNJSrfCOs4Y8Oal-s0Gdrr0od-Je83BjfW_k-4DqLxMdWdJE',
#   'summonerName': 'FriendIy',
#   'leaguePoints': 75,
#   'wins': 31,
#   'losses': 25,
#   'veteran': False,
#   'inactive': False,
#   'freshBlood': False,
#   'hotStreak': False},
#  {'leagueId': '0dbc305d-2d2f-4ca5-8825-928aa01adf6a',
#   'queueType': 'RANKED_SOLO_5x5',
#   'tier': 'DIAMOND',
#   'rank': 'II',
#   'summonerId': 'XQPWr-b5WRpOV75Mmnum853pWiu7v3thTJbk2Qxz7qYKIbbx',
# ...
